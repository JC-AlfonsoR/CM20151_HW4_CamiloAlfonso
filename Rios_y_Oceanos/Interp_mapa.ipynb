# %% [markdown]
# #Interpolando en Mapa

# %% [markdown]
# ####Versiones

# %%
import sys
print(sys.version)
# Out:
# 2.7.7 |Anaconda 2.0.1 (64-bit)| (default, Jun 11 2014, 10:40:02) [MSC v.1500 64 bit (AMD64)]

# %%
from subprocess import call
# !dir
# Out:
#  El volumen de la unidad C es TI105864W0B
#  El n£mero de serie del volumen es: 20E7-A326
#
#  Directorio de C:\Users\J. Camilo\Documents\IPython Notebooks\HW4\Rios_y_Oceanos
#
# 23/03/2015  11:10 p.m.    <DIR>          .
# 23/03/2015  11:10 p.m.    <DIR>          ..
# 23/03/2015  09:40 p.m.    <DIR>          .ipynb_checkpoints
# 22/03/2015  07:22 p.m.           405,721 air.mon.ltm.nc
# 23/03/2015  07:07 p.m.            66,897 data.dat
# 23/03/2015  09:39 p.m.            21,922 figure1.pdf
# 23/03/2015  11:06 p.m.           377,127 interpolation.ipynb
# 23/03/2015  11:24 p.m.           816,547 Interp_mapa.ipynb
# 23/03/2015  11:23 p.m.           361,626 mapa.png
# 23/03/2015  11:21 p.m.           310,943 mapa_interpolado.png
# 22/03/2015  09:50 p.m.               341 netCDF-data_links.txt
# 23/03/2015  07:12 p.m.         1,017,184 Rios.ipynb
# 23/03/2015  07:10 p.m.           285,233 Rios_150.png
# 23/03/2015  07:07 p.m.            22,567 top_300_rios.csv
# 22/03/2015  09:48 p.m.           437,141 world.png
#               12 archivos      4,123,249 bytes
#                3 dirs  65,427,693,568 bytes libres

# %% [markdown]
# ####Leyendo netcdf

# %%
from netCDF4 import Dataset
import numpy as np

# %%
file_name = 'air.mon.ltm.nc'
f = Dataset(file_name, mode='r')
print(f)
# Out:
# <type 'netCDF4.Dataset'>
# root group (NETCDF4_CLASSIC file format):
#     description: Data from NCEP initialized reanalysis (4x/day).  These are the 0.9950 sigma level values
#     platform: Model
#     Conventions: COARDS
#     references: http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanalysis.derived.html
#     not_missing_threshold_percent: minimum 3% values input to have non-missing output value
#     history: Created 2011/07/12 by doMonthLTM
# Converted to chunked, deflated non-packed NetCDF4 2014/09
#     title: monthly ltm air.sig995 from the NCEP Reanalysis
#     dimensions(sizes): lon(144), lat(73), time(12), nbnds(2)
#     variables(dimensions): lat(lat), lon(lon), time(time), climatology_bounds(time,nbnds), air(time,lat,lon), valid_yr_count(time,lat,lon)
#     groups:

# %%
lons = f.variables['lon'][:]
lats = f.variables['lat'][:]
air = f.variables['air'][11,:,:] #Download only one temporal slice
#bnds  =f.variables['climatology_bounds'][:]
f.close()
#G = {}
#G['lon'] = lons[:].squeeze()
#G['lat'] = lats[:].squeeze()
#G['air'] = air[0,:,:].squeeze() # Download only one temporal slice

#G['air'] = np.ma.masked_invalid(G['air'])

# %%
# %pylab inline
from mpl_toolkits.basemap import Basemap
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f', 'griddata']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
figure(figsize(30,10))
lon_0 = lons.mean()
lat_0 = lats.mean()
map = Basemap(projection='cea', lat_0=lat_0, lon_0=lon_0,
              resolution='h', area_thresh=500.0)
map.drawcoastlines()
map.drawcounties()
map.drawmeridians(np.arange(0,360,30))
map.drawparallels(np.arange(-90,90,30))
map.fillcontinents(color='coral',lake_color='aqua')
lon, lat = np.meshgrid(lons, lats)
xi,yi = map(lon, lat)
#cs = map.pcolor(xi,yi,air)
cs = map.contour(xi,yi,air,linewidths=1.5)
cbar = map.colorbar(cs,location='bottom')
#map.plot(xi,yi,'bo')
title('Air temperature - Data from ' + file_name,size=20)
savefig('mapa.png')

# %%
figure(figsize(30,10))

map = Basemap(projection='cea', lat_0=lat_0, lon_0=lon_0,
              resolution='h', area_thresh=500.0)
map.drawcoastlines()
map.drawcounties()
map.drawmeridians(np.arange(0,360,30))
map.drawparallels(np.arange(-90,90,30))

lon, lat = np.meshgrid(lons, lats)
xi,yi = map(lon, lat)
map.plot(xi,yi,'bo')
title('Visualizing position of known data' + file_name,size=20)

# %% [markdown]
# ####Interpolacion 2D

# %%
points = array([lat.ravel(),lon.ravel()]).T #Puntos conocidos
values = air.ravel() #Valores conocidos

#Crear malla mas fina en n_lat, n_lon
new_lats = arange(min(lats),max(lats),1)
new_lons = arange(min(lons),max(lons),1)
n_lon,n_lat = meshgrid(new_lons,new_lats)
print(shape(new_lats))
print(shape(new_lons))
print(shape(n_lat))
# Out:
# (180L,)
# (358L,)
# (180L, 358L)

# %% [markdown]
# ####Interpolacion

# %%
from scipy.interpolate import griddata
grid_interp = griddata(points, values, (n_lat,n_lon), method='nearest')
shape(grid_interp)
# Out:
# (180L, 358L)

# %%
figure(figsize(30,10))
lon_0 = lons.mean()
lat_0 = lats.mean()
map = Basemap(projection='cea', lat_0=lat_0, lon_0=lon_0,
              resolution='h', area_thresh=500.0)
map.drawcoastlines()
map.drawcounties()
map.drawmeridians(np.arange(0,360,30))
map.drawparallels(np.arange(-90,90,30))
map.fillcontinents(color='coral',lake_color='aqua')
#lon, lat = np.meshgrid(lons, lats)
xi,yi = map(n_lon, n_lat)
#cs = map.pcolor(xi,yi,grid_interp)
cs = map.contour(xi,yi,grid_interp,linewidths=1.5)
cbar = map.colorbar(cs,location='bottom', pad="10%")
#map.plot(xi,yi,'bo')
title('Air temperature - Data from ' + file_name,size=20)
savefig('mapa_interpolado.png')
