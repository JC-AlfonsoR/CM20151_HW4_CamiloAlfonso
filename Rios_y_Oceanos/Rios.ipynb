# %% [markdown]
# #Estudiando Rios Y Oceanos

# %% [markdown]
# ####Versiones

# %%
# %pylab inline
from mpl_toolkits.basemap import Basemap
from sys import version
print("Version ",version)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ('Version ', '2.7.7 |Anaconda 2.0.1 (64-bit)| (default, Jun 11 2014, 10:40:02) [MSC v.1500 64 bit (AMD64)]')

# %% [markdown]
# ###Descargar archivos
# Procesar datos para que se puedan leer con pandas

# %%
import urllib

#En python 3
#response = urllib.request.urlopen("http://www.cgd.ucar.edu/cas/catalog/surface/dai-runoff/coastal-stns-byVol-updated-oct2007.txt")

response = urllib.urlopen("http://www.cgd.ucar.edu/cas/catalog/surface/dai-runoff/coastal-stns-byVol-updated-oct2007.txt")
F = open("data.dat","w")
for line in response:
    l = str(line)
    s = l.split()
    ss = s[1]
    for i in range(2,14):
        ss = ss + " " + s[i]
    F.write(ss + "\n")
F.close()

# %% [markdown]
# ###Leer con Pandas

# %%
import pandas as pd
data = pd.read_table("data.dat",sep=" ") #Leer datos
data = data.sort(['m2s_ratio'], ascending=False) #Ordenar datos en orden descendente acorede al flujo
#data = data[["No","m2s_ratio","lonm","latm","River_Name"]] #Seleccionar informacion
data.head()
# Out:
#     m2s_ratio    lonm   latm  area(km2)  Vol(km3/yr)   nyr   yrb   yre  \
# 51      53333    7.25   7.75      60500       10.603  46.8  1930  1989
# 24      36429  -77.25   6.25       9432       55.789  24.2  1966  1990
# 48      33002 -122.25  37.75      60885       21.504  57.0  1948  2006
# 69      22857   86.75  20.75      50000       21.283   1.0  1971  1971
# 28      22319  -58.75   6.25      66600       66.436  28.8  1965  1995
#
#     elev(m)  CT   CN  River_Name  OCN
# 51      173  CM   AF      B�nou�  ATL
# 24       18  CO   SA      Atrato  ATL
# 48        0  US  NaN  Sacramento  PAC
# 69    -9999  IN   AS    Brahmani  IND
# 28       18  GY   SA   Essequibo  ATL

# %% [markdown]
# ###Seleccionar Rios y guardarlos

# %%
#Seleccionar los 300 mayores y guardarlos aparte
n = 300
n_data = data[1:n+1] #Seleccionar los n primero rios de los datos ordenados
n_data.River_Name.str.decode(encoding='latin',errors='strict')
n_data.to_csv("top_300_rios.csv", index=False)

# %% [markdown]
# ### Importar datos

# %%
data = pd.read_csv("top_300_rios.csv")
data.head()
# Out:
#    m2s_ratio    lonm   latm  area(km2)  Vol(km3/yr)   nyr   yrb   yre  \
# 0      36429  -77.25   6.25       9432       55.789  24.2  1966  1990
# 1      33002 -122.25  37.75      60885       21.504  57.0  1948  2006
# 2      22857   86.75  20.75      50000       21.283   1.0  1971  1971
# 3      22319  -58.75   6.25      66600       66.436  28.8  1965  1995
# 4      21111  120.25  34.25     121330       26.971  53.7  1915  1989
#
#    elev(m)  CT   CN  River_Name  OCN
# 0       18  CO   SA      Atrato  ATL
# 1        0  US  NaN  Sacramento  PAC
# 2    -9999  IN   AS    Brahmani  IND
# 3       18  GY   SA   Essequibo  ATL
# 4       25  CN   AS        Huai  PAC

# %% [markdown]
# ###Construir Mapa

# %%
figure(figsize(18,10))
map = Basemap(projection='robin', lat_0=0, lon_0=-100,
              resolution='h', area_thresh=1000.0)
map.drawcoastlines()
map.drawcounties()
map.fillcontinents(color='coral')
map.drawmapboundary()
map.drawmeridians(arange(0,360,30))
map.drawparallels(arange(-90,90,30))


n2 = 150
lons = array(data.lonm[1:n2])
lats = array(data.latm[1:n2])
x,y = map(lons, lats)
map.plot(x, y, 'bo', markersize=5)

labels = list(data.m2s_ratio)
labels = [str(l) for l in labels]
for label, xpt, ypt in zip(labels, x, y):
    plt.text(xpt+3000, ypt+2500, label)

show()

# %%
labels = list(data.m2s_ratio)
labels = [str(l) for l in labels]
print(labels)
# Out:
# ['36429', '33002', '22857', '22319', '21111', '20000', '19444', '19000', '18947', '18636', '18000', '17979', '17838', '17619', '17586', '17500', '17368', '17308', '17059', '16977', '16897', '16744', '16667', '16667', '16062', '16000', '15897', '15882', '15714', '15385', '15313', '15233', '15085', '15000', '14865', '14839', '14762', '14737', '14651', '14576', '14375', '14354', '14286', '13889', '13818', '13600', '13378', '13333', '13333', '13286', '13200', '13143', '12941', '12857', '12857', '12778', '12727', '12703', '12593', '12568', '12545', '12500', '12462', '12414', '12315', '12308', '12295', '12273', '12222', '12217', '12167', '11933', '11919', '11875', '11852', '11818', '11765', '11739', '11724', '11685', '11667', '11600', '11522', '11474', '11458', '11381', '11379', '11379', '11346', '11333', '11282', '11176', '11143', '11111', '11103', '11059', '11053', '11000', '10952', '10882', '10870', '10833', '10833', '10800', '10769', '10741', '10625', '10625', '10597', '10577', '10576', '10566', '10488', '10444', '10443', '10417', '10381', '10378', '10374', '10370', '10370', '10357', '10336', '10313', '10303', '10291', '10274', '10245', '10139', '10120', '10112', '10095', '10069', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000', '10000']

# %% [markdown]
# ###Basemap Tutorial

# %%
from mpl_toolkits.basemap import Basemap
# %pylab inline
#import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
map = Basemap(projection='robin', lat_0=0, lon_0=-100,
              resolution='h', area_thresh=1000.0)
map.drawcoastlines()
map.drawcounties()
map.fillcontinents(color='coral')
map.drawmapboundary()
map.drawmeridians(arange(0,360,30))
map.drawparallels(arange(-90,90,30))
show()

# %%
map = Basemap(projection='merc', lat_0 = 57, lon_0 = -135,
    resolution = 'h', area_thresh = 0.1,
    llcrnrlon=-136.25, llcrnrlat=56.0,
    urcrnrlon=-134.25, urcrnrlat=57.75)
 
map.drawcoastlines()
map.drawcountries()
map.fillcontinents(color = 'coral')
map.drawmapboundary()
 
lons = [-135.3318, -134.8331, -134.6572]
lats = [57.0799, 57.0894, 56.2399]
x,y = map(lons, lats)
map.plot(x, y, 'bo', markersize=10)

labels = ['Sitka', 'Baranof\n  Warm Springs', 'Port Alexander']
x_offsets = [10000, -30000, -25000]
y_offsets = [5000, -25000, -25000]
 
for label, xpt, ypt, x_offset, y_offset in zip(labels, x, y, x_offsets, y_offsets):
    plt.text(xpt+x_offset, ypt+y_offset, label)

plt.show()

# %% [markdown]
# #Intentos fallidos

# %%
import urllib
#response = urllib.request.URLopener("http://www.cgd.ucar.edu/cas/catalog/surface/dai-runoff/coastal-stns-byVol-updated-oct2007.txt")
response = urllib.request.urlopen("http://www.cgd.ucar.edu/cas/catalog/surface/dai-runoff/coastal-stns-byVol-updated-oct2007.txt")
#urlopen('http://www.example.com/')
#html = response.read()
F = open("data.txt","w")
for line in response:
    l = str(line)
    s = l.replace("   "," ")
    s = s.replace("  "," ")
    s = s.replace(" ",",")
    s = s[:-4]
    #ss = ""
    #for j in s:
    #    ss = ss + "," + j
    F.write(s + "\n")
    #print(s)
F.close()

# %%
#Python 3
import urllib.request
# Descargar datos y guardarlos en data.txt
urllib.request.urlretrieve("http://www.cgd.ucar.edu/cas/catalog/surface/dai-runoff/coastal-stns-byVol-updated-oct2007.txt"\
                           , "data.txt")
# Out:
# ('data.txt', <http.client.HTTPMessage at 0x7f21048>)
